# %% [markdown]
# <a href="https://colab.research.google.com/github/AmMorgen/dataTest/blob/main/testeUm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
#esse é meu dataframe
#a função pd.read_csv é uma função do pandas que vai carregar meu csv
df = pd.read_csv('https://raw.githubusercontent.com/AmMorgen/dataTest/main/kpop_idol_followers.csv?token=GHSAT0AAAAAACE4OMWZ77BGQSSGC5GOPAESZGNO4RQ')

df.rename(columns={"Gender.x": "type_group", "Gender.y": "gender"}, inplace = True)


df
# Out:
#     Stage.Name         Group      ig_name  Followers type_group  \
# 0          Ace           VAV      ace.vav     335439        Boy
# 1         Ahra      FAVORITE    ahra.view      12342       Girl
# 2      Ahyoung    DAL SHABET    a_young91      10479       Girl
# 3        Alice   HELLO VENUS     hv_alice      11135       Girl
# 4        Amber          F(X)   ajol_llama    5519743       Girl
# ..         ...           ...          ...        ...        ...
# 401       Zico       BLOCK B  woozico0914    4814973        Boy
# 402        Ziu           VAV      ziu.vav     247204        Boy
# 403         ZN        LABOUM    baejinyea      81988       Girl
# 404       Zuho           SF9    zuuuuu_oh     398744        Boy
# 405       Zuny  LADIES' CODE   zuny_l___l      64731       Girl
#
#                Full.Name Korean.Name K.Stage.Name Date.of.Birth       Debut  \
# 0          Jang Wooyoung         장우영          에이스    1992-08-28  2015-10-31
# ...

# %% [markdown]
# **Histogrmas**

# %%
plt.style.use('dark_background')
df['age'].plot.hist()
plt.title("Idade idols")
plt.xlabel('Faixa idade')
plt.ylabel('numero de pessoas')
# Out:
# Text(0, 0.5, 'numero de pessoas')

# %%
grupo_twice = df.loc[df['Group'].isin(['TWICE'])]
print(grupo_twice)
grupo_twice[['age']].plot.hist()
media_idade = grupo_twice['age'].mean()
grupo_twice
print('A media de idade das integrantes é: {:.1f}'.format(media_idade))
# Out:
#     Stage.Name  Group       ig_name  Followers type_group        Full.Name  \
# 28   Chaeyoung  TWICE      chaeyo.0    8858825       Girl    Son Chaeyoung
# 43      Dahyun  TWICE    dahhyunnee    8081245       Girl       Kim Dahyun
# 145  Jeongyeon  TWICE      jy_piece    7215888       Girl    Yoo Jeongyeon
# 149      Jihyo  TWICE       _zyozyo    8786200       Girl       Park Jisoo
# 211       Mina  TWICE    mina_sr_my    8317566       Girl       Myoui Mina
# 231       Momo  TWICE          momo   11504255       Girl       Hirai Momo
# 242     Nayeon  TWICE     nayeonyny   10757436       Girl        Im Nayeon
# 268       Sana  TWICE    m.by__sana    9887725       Girl  Minatozaki Sana
# 338      Tzuyu  TWICE  thinkaboutzu   11024366       Girl       Chou Tzuyu
#
#     Korean.Name K.Stage.Name Date.of.Birth       Debut  ...      Country  \
# 28          손채영           채영    1999-04-23  2015-10-20  ...  South Korea
# ...

# %%
GirlGruop = df.loc[df['type_group'].isin(['Girl'])]



GirlGruop = GirlGruop['Group'].unique()
GirlGruop
# Out:
# array(['FAVORITE', 'DAL SHABET', 'HELLO VENUS', 'F(X)', 'PINK FANTASY',
#        'TAHITI', 'OH MY GIRL', "LADIES' CODE", 'LOVELYZ', 'APINK', 'WJSN',
#        'CHERRY BULLET', 'NATURE', 'ALICE', 'LE SSERAFIM', 'IZ*ONE',
#        'FROMIS_9', 'TWICE', 'AOA', 'FANATICS', 'CRAYON POP', 'LOONA',
#        'SONAMOO', '2EYES', 'HI-L', 'DREAMCATCHER', 'WEKI MEKI',
#        'AFTER SCHOOL', 'CLC', 'DIA', 'VIVIZ', 'BRAVE GIRLS', 'T-ARA',
#        'HINAPIA', 'BROWN EYED GIRLS', 'BERRY GOOD', 'GUGUDAN', 'LABOUM',
#        '3YE', 'EXID', 'MAMAMOO', 'MOMOLAND', '9MUSES', "GIRL'S DAY",
#        'BESTIE', 'UNI.T', 'RED VELVET', 'BLACKPINK', 'WASSUP', 'BVNDIT',
#        'GWSN', '(G)I-DLE', 'APRIL', 'CHECKMATE', 'ARIAZ', 'GFRIEND',
#        'IVE'], dtype=object)

# %%
GirlGruop = df.loc[df['type_group'].isin(['Girl'])]
GirlGruop['age'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
media_idade = GirlGruop['age'].mean()
print(media_idade)
# Out:
# 26.606694560669457

# %%
GirlGruop = df.loc[df['type_group'].isin(['Girl'])]
GirlGruop['Date.of.Birth'] = pd.to_datetime(GirlGruop['Date.of.Birth'], format='%Y-%m-%d')
data_mais_antiga = GirlGruop['Date.of.Birth'].min()
nome_data_antiga = GirlGruop.loc[GirlGruop['Date.of.Birth'] == data_mais_antiga, 'Stage.Name'].iloc[0]
print(data_mais_antiga)
print(nome_data_antiga)
# Out:
# 1981-11-02 00:00:00
# Miryo
# <ipython-input-17-70a9ff206703>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   GirlGruop['Date.of.Birth'] = pd.to_datetime(GirlGruop['Date.of.Birth'], format='%Y-%m-%d')
